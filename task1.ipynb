# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/saniy/Downloads/API_SP.POP.TOTL_DS2_en_csv_v2_38144/API_SP.POP.TOTL_DS2_en_csv_v2_38144.csv", skiprows=4)

# %%
df
# Out:
#                     Country Name Country Code     Indicator Name  \
# 0                          Aruba          ABW  Population, total
# 1    Africa Eastern and Southern          AFE  Population, total
# 2                    Afghanistan          AFG  Population, total
# 3     Africa Western and Central          AFW  Population, total
# 4                         Angola          AGO  Population, total
# ..                           ...          ...                ...
# 261                       Kosovo          XKX  Population, total
# 262                  Yemen, Rep.          YEM  Population, total
# 263                 South Africa          ZAF  Population, total
# 264                       Zambia          ZMB  Population, total
# 265                     Zimbabwe          ZWE  Population, total
#
#     Indicator Code         1960         1961         1962         1963  \
# 0      SP.POP.TOTL      54922.0      55578.0      56320.0      57002.0
# 1      SP.POP.TOTL  130075728.0  133534923.0  137171659.0  140945536.0
# 2      SP.POP.TOTL    9035043.0    9214083.0    9404406.0    9604487.0
# 3      SP.POP.TOTL   97630925.0   99706674.0  101854756.0  104089175.0
# 4      SP.POP.TOTL    5231654.0    5301583.0    5354310.0    5408320.0
# ..             ...          ...          ...          ...          ...
# 261    SP.POP.TOTL     984846.0    1011421.0    1036950.0    1062737.0
# 262    SP.POP.TOTL    5532301.0    5655232.0    5782221.0    5911135.0
# 263    SP.POP.TOTL   16440172.0   16908035.0   17418522.0   17954564.0
# 264    SP.POP.TOTL    3153729.0    3254086.0    3358099.0    3465907.0
# 265    SP.POP.TOTL    3809389.0    3930401.0    4055959.0    4185877.0
#
#             1964         1965  ...         2016         2017         2018  \
# 0        57619.0      58190.0  ...     108727.0     108735.0     108908.0
# 1    144904094.0  149033472.0  ...  623369401.0  640058741.0  657801085.0
# 2      9814318.0   10036008.0  ...   34700612.0   35688935.0   36743039.0
# 3    106388440.0  108772632.0  ...  429454743.0  440882906.0  452195915.0
# 4      5464187.0    5521981.0  ...   29183070.0   30234839.0   31297155.0
# ..           ...          ...  ...          ...          ...          ...
# 261    1090270.0    1120168.0  ...    1777568.0    1791019.0    1797086.0
# 262    6048006.0    6195593.0  ...   32109010.0   33090921.0   34085182.0
# 263   18511361.0   19089380.0  ...   57259551.0   57635162.0   58613001.0
# 264    3577017.0    3692086.0  ...   16914423.0   17441320.0   17973569.0
# 265    4320006.0    4458462.0  ...   14600294.0   14812482.0   15034452.0
#
#             2019         2020         2021         2022         2023  \
# 0       109203.0     108587.0     107700.0     107310.0     107359.0
# 1    675950189.0  694446100.0  713090928.0  731821393.0  750503764.0
# 2     37856121.0   39068979.0   40000412.0   40578842.0   41454761.0
# 3    463365429.0  474569351.0  485920997.0  497387180.0  509398589.0
# 4     32375632.0   33451132.0   34532429.0   35635029.0   36749906.0
# ..           ...          ...          ...          ...          ...
# 261    1788891.0    1790151.0    1786079.0    1768096.0    1682668.0
# 262   35111408.0   36134863.0   37140230.0   38222876.0   39390799.0
# 263   59587885.0   60562381.0   61502603.0   62378410.0   63212384.0
# 264   18513839.0   19059395.0   19603607.0   20152938.0   20723965.0
# 265   15271368.0   15526888.0   15797210.0   16069056.0   16340822.0
#
#             2024  Unnamed: 69
# 0       107624.0          NaN
# 1    769294618.0          NaN
# 2     42647492.0          NaN
# 3    521764076.0          NaN
# 4     37885849.0          NaN
# ..           ...          ...
# 261    1527324.0          NaN
# 262   40583164.0          NaN
# 263   64007187.0          NaN
# 264   21314956.0          NaN
# 265   16634373.0          NaN
#
# [266 rows x 70 columns]

# %%
# shape check
df.shape
# Out:
# (266, 70)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 70 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   1960            264 non-null    float64
#  5   1961            264 non-null    float64
#  6   1962            264 non-null    float64
#  7   1963            264 non-null    float64
#  8   1964            264 non-null    float64
#  9   1965            264 non-null    float64
#  10  1966            264 non-null    float64
#  11  1967            264 non-null    float64
#  12  1968            264 non-null    float64
#  13  1969            264 non-null    float64
#  14  1970            264 non-null    float64
#  15  1971            264 non-null    float64
#  16  1972            264 non-null    float64
#  17  1973            264 non-null    float64
#  18  1974            264 non-null    float64
#  19  1975            264 non-null    float64
#  20  1976            264 non-null    float64
#  21  1977            264 non-null    float64
#  22  1978            264 non-null    float64
#  23  1979            264 non-null    float64
#  24  1980            264 non-null    float64
#  25  1981            264 non-null    float64
#  26  1982            264 non-null    float64
#  27  1983            264 non-null    float64
#  28  1984            264 non-null    float64
#  29  1985            264 non-null    float64
#  30  1986            264 non-null    float64
#  31  1987            264 non-null    float64
#  32  1988            264 non-null    float64
#  33  1989            264 non-null    float64
#  34  1990            265 non-null    float64
#  35  1991            265 non-null    float64
#  36  1992            265 non-null    float64
#  37  1993            265 non-null    float64
#  38  1994            265 non-null    float64
#  39  1995            265 non-null    float64
#  40  1996            265 non-null    float64
#  41  1997            265 non-null    float64
#  42  1998            265 non-null    float64
#  43  1999            265 non-null    float64
#  44  2000            265 non-null    float64
#  45  2001            265 non-null    float64
#  46  2002            265 non-null    float64
#  47  2003            265 non-null    float64
#  48  2004            265 non-null    float64
#  49  2005            265 non-null    float64
#  50  2006            265 non-null    float64
#  51  2007            265 non-null    float64
#  52  2008            265 non-null    float64
#  53  2009            265 non-null    float64
#  54  2010            265 non-null    float64
#  55  2011            265 non-null    float64
#  56  2012            265 non-null    float64
#  57  2013            265 non-null    float64
#  58  2014            265 non-null    float64
#  59  2015            265 non-null    float64
#  60  2016            265 non-null    float64
#  61  2017            265 non-null    float64
#  62  2018            265 non-null    float64
#  63  2019            265 non-null    float64
#  64  2020            265 non-null    float64
#  65  2021            265 non-null    float64
#  66  2022            265 non-null    float64
#  67  2023            265 non-null    float64
#  68  2024            265 non-null    float64
#  69  Unnamed: 69     0 non-null      float64
# dtypes: float64(66), object(4)
# memory usage: 145.6+ KB

# %%
df.describe()
# Out:
#                1960          1961          1962          1963          1964  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   1.154023e+08  1.170070e+08  1.191678e+08  1.218381e+08  1.245322e+08
# std    3.616526e+08  3.661347e+08  3.727681e+08  3.813687e+08  3.900162e+08
# min    2.715000e+03  2.970000e+03  3.264000e+03  3.584000e+03  3.922000e+03
# 25%    5.152028e+05  5.255230e+05  5.363018e+05  5.475875e+05  5.593638e+05
# 50%    3.659633e+06  3.747132e+06  3.831900e+06  3.919710e+06  4.010150e+06
# 75%    2.686293e+07  2.761326e+07  2.837302e+07  2.915448e+07  2.995223e+07
# max    3.021513e+09  3.062768e+09  3.117372e+09  3.184063e+09  3.251253e+09
#
#                1965          1966          1967          1968          1969  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   1.272581e+08  1.301037e+08  1.329570e+08  1.358851e+08  1.389115e+08
# std    3.987697e+08  4.079989e+08  4.172145e+08  4.266937e+08  4.365313e+08
# min    4.282000e+03  4.664000e+03  5.071000e+03  5.500000e+03  5.631000e+03
# 25%    5.675750e+05  5.711695e+05  5.779525e+05  5.825170e+05  5.861185e+05
# 50%    4.102976e+06  4.198738e+06  4.297792e+06  4.396290e+06  4.503420e+06
# 75%    3.075921e+07  3.147516e+07  3.203946e+07  3.247057e+07  3.277149e+07
# max    3.318998e+09  3.389087e+09  3.459015e+09  3.530704e+09  3.604816e+09
#
#        ...          2016          2017          2018          2019  \
# count  ...  2.650000e+02  2.650000e+02  2.650000e+02  2.650000e+02
# mean   ...  3.040350e+08  3.078574e+08  3.116049e+08  3.152801e+08
# std    ...  9.447450e+08  9.557617e+08  9.664403e+08  9.768047e+08
# min    ...  1.093000e+04  1.086900e+04  1.075100e+04  1.058100e+04
# 25%    ...  1.777568e+06  1.791019e+06  1.797086e+06  1.788891e+06
# 50%    ...  1.032545e+07  1.025915e+07  1.028382e+07  1.042338e+07
# 75%    ...  6.011522e+07  6.000225e+07  6.014866e+07  5.972908e+07
# max    ...  7.529067e+09  7.614749e+09  7.697492e+09  7.778304e+09
#
#                2020          2021          2022          2023          2024  \
# count  2.650000e+02  2.650000e+02  2.650000e+02  2.650000e+02  2.650000e+02
# mean   3.187967e+08  3.219557e+08  3.251253e+08  3.284356e+08  3.318869e+08
# std    9.866025e+08  9.952966e+08  1.003734e+09  1.012519e+09  1.021734e+09
# min    1.039900e+04  1.019400e+04  9.992000e+03  9.816000e+03  9.646000e+03
# 25%    1.790151e+06  1.786079e+06  1.803545e+06  1.827816e+06  1.792179e+06
# 50%    1.069786e+07  1.050577e+07  1.048694e+07  1.064485e+07  1.087698e+07
# 75%    6.097280e+07  6.283041e+07  6.471182e+07  6.661761e+07  6.851670e+07
# max    7.855075e+09  7.920862e+09  7.990400e+09  8.064977e+09  8.142056e+09
#
#        Unnamed: 69
# count          0.0
# mean           NaN
# std            NaN
# min            NaN
# 25%            NaN
# 50%            NaN
# 75%            NaN
# max            NaN
#
# [8 rows x 66 columns]

# %%
df.isna().sum()
# Out:
# Country Name        0
# Country Code        0
# Indicator Name      0
# Indicator Code      0
# 1960                2
#                  ...
# 2021                1
# 2022                1
# 2023                1
# 2024                1
# Unnamed: 69       266
# Length: 70, dtype: int64

# %%
# Drop unuseful columns
df.drop(columns=['Country Code','Indicator Name'],inplace=True)

# %%
df.sample()
# Out:
#     Country Name Indicator Code       1960       1961       1962       1963  \
# 195     Paraguay    SP.POP.TOTL  1883514.0  1927394.0  1973130.0  2021909.0
#
#           1964       1965       1966       1967  ...       2016       2017  \
# 195  2073119.0  2125177.0  2177584.0  2229994.0  ...  6249126.0  6338660.0
#
#           2018       2019       2020       2021       2022       2023  \
# 195  6427382.0  6515058.0  6603739.0  6684182.0  6760464.0  6844146.0
#
#           2024  Unnamed: 69
# 195  6929153.0          NaN
#
# [1 rows x 68 columns]

# %%
# filter data for total population
total_population_df=df[df['Indicator Code']=='SP.POP.TOTL']
total_population_df
# Out:
#                     Country Name Indicator Code         1960         1961  \
# 0                          Aruba    SP.POP.TOTL      54922.0      55578.0
# 1    Africa Eastern and Southern    SP.POP.TOTL  130075728.0  133534923.0
# 2                    Afghanistan    SP.POP.TOTL    9035043.0    9214083.0
# 3     Africa Western and Central    SP.POP.TOTL   97630925.0   99706674.0
# 4                         Angola    SP.POP.TOTL    5231654.0    5301583.0
# ..                           ...            ...          ...          ...
# 261                       Kosovo    SP.POP.TOTL     984846.0    1011421.0
# 262                  Yemen, Rep.    SP.POP.TOTL    5532301.0    5655232.0
# 263                 South Africa    SP.POP.TOTL   16440172.0   16908035.0
# 264                       Zambia    SP.POP.TOTL    3153729.0    3254086.0
# 265                     Zimbabwe    SP.POP.TOTL    3809389.0    3930401.0
#
#             1962         1963         1964         1965         1966  \
# 0        56320.0      57002.0      57619.0      58190.0      58694.0
# 1    137171659.0  140945536.0  144904094.0  149033472.0  153281203.0
# 2      9404406.0    9604487.0    9814318.0   10036008.0   10266395.0
# 3    101854756.0  104089175.0  106388440.0  108772632.0  111246953.0
# 4      5354310.0    5408320.0    5464187.0    5521981.0    5581386.0
# ..           ...          ...          ...          ...          ...
# 261    1036950.0    1062737.0    1090270.0    1120168.0    1152586.0
# 262    5782221.0    5911135.0    6048006.0    6195593.0    6351494.0
# 263   17418522.0   17954564.0   18511361.0   19089380.0   19690087.0
# 264    3358099.0    3465907.0    3577017.0    3692086.0    3812003.0
# 265    4055959.0    4185877.0    4320006.0    4458462.0    4601217.0
#
#             1967  ...         2016         2017         2018         2019  \
# 0        58990.0  ...     108727.0     108735.0     108908.0     109203.0
# 1    157704381.0  ...  623369401.0  640058741.0  657801085.0  675950189.0
# 2     10505959.0  ...   34700612.0   35688935.0   36743039.0   37856121.0
# 3    113795019.0  ...  429454743.0  440882906.0  452195915.0  463365429.0
# 4      5641807.0  ...   29183070.0   30234839.0   31297155.0   32375632.0
# ..           ...  ...          ...          ...          ...          ...
# 261    1187667.0  ...    1777568.0    1791019.0    1797086.0    1788891.0
# 262    6516444.0  ...   32109010.0   33090921.0   34085182.0   35111408.0
# 263   20314066.0  ...   57259551.0   57635162.0   58613001.0   59587885.0
# 264    3936343.0  ...   16914423.0   17441320.0   17973569.0   18513839.0
# 265    4748307.0  ...   14600294.0   14812482.0   15034452.0   15271368.0
#
#             2020         2021         2022         2023         2024  \
# 0       108587.0     107700.0     107310.0     107359.0     107624.0
# 1    694446100.0  713090928.0  731821393.0  750503764.0  769294618.0
# 2     39068979.0   40000412.0   40578842.0   41454761.0   42647492.0
# 3    474569351.0  485920997.0  497387180.0  509398589.0  521764076.0
# 4     33451132.0   34532429.0   35635029.0   36749906.0   37885849.0
# ..           ...          ...          ...          ...          ...
# 261    1790151.0    1786079.0    1768096.0    1682668.0    1527324.0
# 262   36134863.0   37140230.0   38222876.0   39390799.0   40583164.0
# 263   60562381.0   61502603.0   62378410.0   63212384.0   64007187.0
# 264   19059395.0   19603607.0   20152938.0   20723965.0   21314956.0
# 265   15526888.0   15797210.0   16069056.0   16340822.0   16634373.0
#
#      Unnamed: 69
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ..           ...
# 261          NaN
# 262          NaN
# 263          NaN
# 264          NaN
# 265          NaN
#
# [266 rows x 68 columns]

# %%
# sort data based on total population for 2022
total_population_sort = total_population_df.sort_values(by='2022',ascending=False)
total_population_sort
# Out:
#                  Country Name Indicator Code          1960          1961  \
# 259                     World    SP.POP.TOTL  3.021513e+09  3.062768e+09
# 103          IDA & IBRD total    SP.POP.TOTL  2.289192e+09  2.321079e+09
# 140       Low & middle income    SP.POP.TOTL  2.083719e+09  2.112957e+09
# 156             Middle income    SP.POP.TOTL  1.968969e+09  1.995508e+09
# 102                 IBRD only    SP.POP.TOTL  1.893705e+09  1.915613e+09
# ..                        ...            ...           ...           ...
# 147  St. Martin (French part)    SP.POP.TOTL  4.250000e+03  4.386000e+03
# 188                     Palau    SP.POP.TOTL  9.328000e+03  9.555000e+03
# 179                     Nauru    SP.POP.TOTL  4.607000e+03  4.774000e+03
# 245                    Tuvalu    SP.POP.TOTL  5.598000e+03  5.648000e+03
# 110            Not classified    SP.POP.TOTL           NaN           NaN
#
#              1962          1963          1964          1965          1966  \
# 259  3.117372e+09  3.184063e+09  3.251253e+09  3.318998e+09  3.389087e+09
# 103  2.366118e+09  2.423349e+09  2.481068e+09  2.539564e+09  2.600930e+09
# 140  2.155317e+09  2.209806e+09  2.264731e+09  2.320529e+09  2.379893e+09
# 156  2.035070e+09  2.086652e+09  2.138528e+09  2.191141e+09  2.247186e+09
# 102  1.950275e+09  1.996753e+09  2.043310e+09  2.090210e+09  2.139609e+09
# ..            ...           ...           ...           ...           ...
# 147  4.527000e+03  4.673000e+03  4.827000e+03  4.996000e+03  5.213000e+03
# 188  9.793000e+03  1.003700e+04  1.029200e+04  1.054700e+04  1.080500e+04
# 179  4.979000e+03  5.226000e+03  5.515000e+03  5.832000e+03  6.043000e+03
# 245  5.699000e+03  5.751000e+03  5.752000e+03  5.715000e+03  5.686000e+03
# 110           NaN           NaN           NaN           NaN           NaN
#
#              1967  ...          2016          2017          2018  \
# 259  3.459015e+09  ...  7.529067e+09  7.614749e+09  7.697492e+09
# 103  2.662675e+09  ...  6.360340e+09  6.440237e+09  6.518317e+09
# 140  2.439438e+09  ...  6.017298e+09  6.094197e+09  6.169917e+09
# 156  2.303229e+09  ...  5.516149e+09  5.579306e+09  5.640395e+09
# 102  2.188950e+09  ...  4.721754e+09  4.765999e+09  4.807240e+09
# ..            ...  ...           ...           ...           ...
# 147  5.472000e+03  ...  3.717500e+04  3.683700e+04  3.601200e+04
# 188  1.098800e+04  ...  1.779700e+04  1.781200e+04  1.781400e+04
# 179  6.135000e+03  ...  1.115000e+04  1.132400e+04  1.147700e+04
# 245  5.652000e+03  ...  1.093000e+04  1.086900e+04  1.075100e+04
# 110           NaN  ...           NaN           NaN           NaN
#
#              2019          2020          2021          2022          2023  \
# 259  7.778304e+09  7.855075e+09  7.920862e+09  7.990400e+09  8.064977e+09
# 103  6.594503e+09  6.666780e+09  6.732973e+09  6.795050e+09  6.858864e+09
# 140  6.243849e+09  6.314223e+09  6.378646e+09  6.438272e+09  6.499219e+09
# 156  5.698868e+09  5.753580e+09  5.802569e+09  5.846791e+09  5.891445e+09
# 102  4.845361e+09  4.878606e+09  4.905534e+09  4.928522e+09  4.952555e+09
# ..            ...           ...           ...           ...           ...
# 147  3.426700e+04  3.178600e+04  2.996100e+04  2.887000e+04  2.751500e+04
# 188  1.779800e+04  1.779200e+04  1.778300e+04  1.775900e+04  1.772700e+04
# 179  1.158700e+04  1.164300e+04  1.170900e+04  1.180100e+04  1.187500e+04
# 245  1.058100e+04  1.039900e+04  1.019400e+04  9.992000e+03  9.816000e+03
# 110           NaN           NaN           NaN           NaN           NaN
#
#              2024  Unnamed: 69
# 259  8.142056e+09          NaN
# 103  6.926456e+09          NaN
# 140  6.563720e+09          NaN
# 156  5.939112e+09          NaN
# 102  4.979720e+09          NaN
# ..            ...          ...
# 147  2.612900e+04          NaN
# 188  1.769500e+04          NaN
# 179  1.194700e+04          NaN
# 245  9.646000e+03          NaN
# 110           NaN          NaN
#
# [266 rows x 68 columns]

# %% [markdown]
# top countries with highest population in 2022

# %% [markdown]
# #
# top 10 countries with the highest population for 2022
# top_ten_countries = total_population_sort.head(10)
# print("Top Ten Counteies Of Total Population:-")
# print(top_ten_countries)

# %% [markdown]
# DATA VISUALIZATION

# %%
# Data visualization
def add_value_labels(ax,spacing=10):
    for rect in ax.patches:
        x=rect.get_x()+rect.get_width()/2
        y=rect.get_height()-3
        
        va='bottom' if y>=0 else 'top'
        label= '()'.format(y) 
        y_shift = spacing * (1 if y >= 0 else -1)
        ax.annotate(label,(x,y),xytext=(0,y_shift),textcoords="offset points",ha='center',va=va)

# %% [markdown]
# Top ten counteirs of total population in year 2022 and 2000

# %%
# create a bar plot
plt.figure(figsize=(20,13))
plt.rcParams['axes.facecolor']=="black"

plt.subplot(2,2,1)
plot=sns.barplot(x='2022',y="Country Name",data=top_ten_countries,palette="coolwarm")
plt.title("Top Ten countries Of Total Population (2022)")
plt.xlabel("Total population")
plt.ylabel("country")
add_value_labels(plot)

plt.subplot(2,2,2)
plot=sns.barplot(x='2000',y="Country Name",data=top_ten_countries,palette="coolwarm")
plt.title("Top Ten countries Of Total Population in 2000")
plt.xlabel("Total population")
plt.ylabel("country")
add_value_labels(plot)

plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 6
#       3 plt.rcParams['axes.facecolor']=="black"
#       5 plt.subplot(2,2,1)
# ----> 6 plot=sns.barplot(x='2022',y="Country Name",data=top_ten_countries,palette="coolwarm")
#       7 plt.title("Top Ten countries Of Total Population (2022)")
#       8 plt.xlabel("Total population")
#
# NameError: name 'top_ten_countries' is not defined

# %% [markdown]
# Top ten counteirs of total population in year 1999 and 1989

# %%
# create a bar plot
plt.figure(figsize=(20,13))
plt.rcParams['axes.facecolor']=="black"

plt.subplot(2,2,1)
plot=sns.barplot(x='1999',y="Country Name",data=top_ten_countries,palette="coolwarm")
plt.title("Top Ten countries Of Total Population (1999)")
plt.xlabel("Total population")
plt.ylabel("country")
add_value_labels(plot)

plt.subplot(2,2,2)
plot=sns.barplot(x='1989',y="Country Name",data=top_ten_countries,palette="coolwarm")
plt.title("Top Ten countries Of Total Population in 1989")
plt.xlabel("Total population")
plt.ylabel("country")
add_value_labels(plot)

plt.tight_layout()

# %%
# sort data based on total population for 2022
total_population_sort_bt = total_population_df.sort_values(by='2022',ascending=True)
total_population_sort_bt
# Out:
#                  Country Name Indicator Code          1960          1961  \
# 245                    Tuvalu    SP.POP.TOTL  5.598000e+03  5.648000e+03
# 179                     Nauru    SP.POP.TOTL  4.607000e+03  4.774000e+03
# 188                     Palau    SP.POP.TOTL  9.328000e+03  9.555000e+03
# 147  St. Martin (French part)    SP.POP.TOTL  4.250000e+03  4.386000e+03
# 212                San Marino    SP.POP.TOTL  1.542800e+04  1.579900e+04
# ..                        ...            ...           ...           ...
# 156             Middle income    SP.POP.TOTL  1.968969e+09  1.995508e+09
# 140       Low & middle income    SP.POP.TOTL  2.083719e+09  2.112957e+09
# 103          IDA & IBRD total    SP.POP.TOTL  2.289192e+09  2.321079e+09
# 259                     World    SP.POP.TOTL  3.021513e+09  3.062768e+09
# 110            Not classified    SP.POP.TOTL           NaN           NaN
#
#              1962          1963          1964          1965          1966  \
# 245  5.699000e+03  5.751000e+03  5.752000e+03  5.715000e+03  5.686000e+03
# 179  4.979000e+03  5.226000e+03  5.515000e+03  5.832000e+03  6.043000e+03
# 188  9.793000e+03  1.003700e+04  1.029200e+04  1.054700e+04  1.080500e+04
# 147  4.527000e+03  4.673000e+03  4.827000e+03  4.996000e+03  5.213000e+03
# 212  1.618300e+04  1.658000e+04  1.697700e+04  1.730500e+04  1.752300e+04
# ..            ...           ...           ...           ...           ...
# 156  2.035070e+09  2.086652e+09  2.138528e+09  2.191141e+09  2.247186e+09
# 140  2.155317e+09  2.209806e+09  2.264731e+09  2.320529e+09  2.379893e+09
# 103  2.366118e+09  2.423349e+09  2.481068e+09  2.539564e+09  2.600930e+09
# 259  3.117372e+09  3.184063e+09  3.251253e+09  3.318998e+09  3.389087e+09
# 110           NaN           NaN           NaN           NaN           NaN
#
#              1967  ...          2016          2017          2018  \
# 245  5.652000e+03  ...  1.093000e+04  1.086900e+04  1.075100e+04
# 179  6.135000e+03  ...  1.115000e+04  1.132400e+04  1.147700e+04
# 188  1.098800e+04  ...  1.779700e+04  1.781200e+04  1.781400e+04
# 147  5.472000e+03  ...  3.717500e+04  3.683700e+04  3.601200e+04
# 212  1.768800e+04  ...  3.310100e+04  3.382500e+04  3.452200e+04
# ..            ...  ...           ...           ...           ...
# 156  2.303229e+09  ...  5.516149e+09  5.579306e+09  5.640395e+09
# 140  2.439438e+09  ...  6.017298e+09  6.094197e+09  6.169917e+09
# 103  2.662675e+09  ...  6.360340e+09  6.440237e+09  6.518317e+09
# 259  3.459015e+09  ...  7.529067e+09  7.614749e+09  7.697492e+09
# 110           NaN  ...           NaN           NaN           NaN
#
#              2019          2020          2021          2022          2023  \
# 245  1.058100e+04  1.039900e+04  1.019400e+04  9.992000e+03  9.816000e+03
# 179  1.158700e+04  1.164300e+04  1.170900e+04  1.180100e+04  1.187500e+04
# 188  1.779800e+04  1.779200e+04  1.778300e+04  1.775900e+04  1.772700e+04
# 147  3.426700e+04  3.178600e+04  2.996100e+04  2.887000e+04  2.751500e+04
# 212  3.466300e+04  3.477000e+04  3.425200e+04  3.375500e+04  3.386000e+04
# ..            ...           ...           ...           ...           ...
# 156  5.698868e+09  5.753580e+09  5.802569e+09  5.846791e+09  5.891445e+09
# 140  6.243849e+09  6.314223e+09  6.378646e+09  6.438272e+09  6.499219e+09
# 103  6.594503e+09  6.666780e+09  6.732973e+09  6.795050e+09  6.858864e+09
# 259  7.778304e+09  7.855075e+09  7.920862e+09  7.990400e+09  8.064977e+09
# 110           NaN           NaN           NaN           NaN           NaN
#
#              2024  Unnamed: 69
# 245  9.646000e+03          NaN
# 179  1.194700e+04          NaN
# 188  1.769500e+04          NaN
# 147  2.612900e+04          NaN
# 212  3.397700e+04          NaN
# ..            ...          ...
# 156  5.939112e+09          NaN
# 140  6.563720e+09          NaN
# 103  6.926456e+09          NaN
# 259  8.142056e+09          NaN
# 110           NaN          NaN
#
# [266 rows x 68 columns]

# %%
top_ten_bt_countries = total_population_sort_bt.head(10)
print("Top Ten Bottom Counteies Of Total Population:-")
print(top_ten_bt_countries)
# Out:
# Top Ten Bottom Counteies Of Total Population:-
#                  Country Name Indicator Code     1960     1961     1962  \
# 245                    Tuvalu    SP.POP.TOTL   5598.0   5648.0   5699.0
# 179                     Nauru    SP.POP.TOTL   4607.0   4774.0   4979.0
# 188                     Palau    SP.POP.TOTL   9328.0   9555.0   9793.0
# 147  St. Martin (French part)    SP.POP.TOTL   4250.0   4386.0   4527.0
# 212                San Marino    SP.POP.TOTL  15428.0  15799.0  16183.0
# 84                  Gibraltar    SP.POP.TOTL  21839.0  21872.0  22197.0
# 255    British Virgin Islands    SP.POP.TOTL   7950.0   8034.0   8070.0
# 149                    Monaco    SP.POP.TOTL  21808.0  21901.0  22078.0
# 137             Liechtenstein    SP.POP.TOTL  16451.0  16877.0  17443.0
# 155          Marshall Islands    SP.POP.TOTL  14703.0  15219.0  15755.0
#
#         1963     1964     1965     1966     1967  ...     2016     2017  \
# 245   5751.0   5752.0   5715.0   5686.0   5652.0  ...  10930.0  10869.0
# 179   5226.0   5515.0   5832.0   6043.0   6135.0  ...  11150.0  11324.0
# 188  10037.0  10292.0  10547.0  10805.0  10988.0  ...  17797.0  17812.0
# 147   4673.0   4827.0   4996.0   5213.0   5472.0  ...  37175.0  36837.0
# 212  16580.0  16977.0  17305.0  17523.0  17688.0  ...  33101.0  33825.0
# 84   22753.0  23315.0  23878.0  24444.0  25015.0  ...  33658.0  34245.0
# 255   8114.0   8168.0   8257.0   8413.0   8646.0  ...  33878.0  32699.0
# 149  22385.0  22686.0  22941.0  23131.0  23230.0  ...  37276.0  37678.0
# 137  18093.0  18755.0  19195.0  19610.0  20175.0  ...  37716.0  37962.0
# 155  16302.0  16852.0  17402.0  17927.0  18655.0  ...  47709.0  46529.0
#
#         2018     2019     2020     2021     2022     2023     2024  \
# 245  10751.0  10581.0  10399.0  10194.0   9992.0   9816.0   9646.0
# 179  11477.0  11587.0  11643.0  11709.0  11801.0  11875.0  11947.0
# 188  17814.0  17798.0  17792.0  17783.0  17759.0  17727.0  17695.0
# 147  36012.0  34267.0  31786.0  29961.0  28870.0  27515.0  26129.0
# 212  34522.0  34663.0  34770.0  34252.0  33755.0  33860.0  33977.0
# 84   34854.0  35494.0  36173.0  36858.0  37609.0  38471.0  39329.0
# 255  34657.0  36395.0  37135.0  37809.0  38319.0  38985.0  39471.0
# 149  38154.0  38109.0  38050.0  38527.0  38931.0  38956.0  38631.0
# 137  38246.0  38563.0  38901.0  39182.0  39493.0  39850.0  40197.0
# 155  45285.0  44007.0  42706.0  41367.0  40077.0  38827.0  37548.0
#
#      Unnamed: 69
# 245          NaN
# 179          NaN
# 188          NaN
# 147          NaN
# 212          NaN
# 84           NaN
# 255          NaN
# 149          NaN
# 137          NaN
# 155          NaN
#
# [10 rows x 68 columns]

# %% [markdown]
# Bottom ten countries of total population in year 2022 and 2000

# %%
# create a bar plot
plt.figure(figsize=(20,13))
plt.rcParams['axes.facecolor']=="black"

plt.subplot(2,2,1)
plot=sns.barplot(x='2022',y="Country Name",data=top_ten_bt_countries,palette="coolwarm")
plt.title("Top Ten Bottom countries Of Total Population (2022)")
plt.xlabel("Total population")
plt.ylabel("country")
add_value_labels(plot)

plt.subplot(2,2,2)
plot=sns.barplot(x='2000',y="Country Name",data=top_ten_bt_countries,palette="coolwarm")
plt.title("Top Ten Bottom countries Of Total Population in 2000")
plt.xlabel("Total population")
plt.ylabel("country")
add_value_labels(plot)

plt.tight_layout()
# Out:
# C:\Users\saniy\AppData\Local\Temp\ipykernel_27680\4024833175.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   plot=sns.barplot(x='2022',y="Country Name",data=top_ten_bt_countries,palette="coolwarm")
# C:\Users\saniy\AppData\Local\Temp\ipykernel_27680\4024833175.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   plot=sns.barplot(x='2000',y="Country Name",data=top_ten_bt_countries,palette="coolwarm")

# %% [markdown]
# Bottom ten countries  in year 1999 and 1989

# %%
# create a bar plot
plt.figure(figsize=(20,13))
plt.rcParams['axes.facecolor']=="black"

plt.subplot(2,2,1)
plot=sns.barplot(x='1999',y="Country Name",data=top_ten_bt_countries,palette="coolwarm")
plt.title("Top Ten Bottom countries Of Total Population (1999)")
plt.xlabel("Total population")
plt.ylabel("country")
add_value_labels(plot)

plt.subplot(2,2,2)
plot=sns.barplot(x='1989',y="Country Name",data=top_ten_bt_countries,palette="coolwarm")
plt.title("Top Ten Bottom countries Of Total Population in 1989")
plt.xlabel("Total population")
plt.ylabel("country")
add_value_labels(plot)

plt.tight_layout()
# Out:
# C:\Users\saniy\AppData\Local\Temp\ipykernel_27680\2372171162.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   plot=sns.barplot(x='1999',y="Country Name",data=top_ten_bt_countries,palette="coolwarm")
# C:\Users\saniy\AppData\Local\Temp\ipykernel_27680\2372171162.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   plot=sns.barplot(x='1989',y="Country Name",data=top_ten_bt_countries,palette="coolwarm")

# %% [markdown]
# Bottom ten countries  in year 1960 and 2022

# %%
# create a bar plot
plt.figure(figsize=(20,13))
plt.rcParams['axes.facecolor']=="black"

plt.subplot(2,2,1)
plot=sns.barplot(x='1960',y="Country Name",data=top_ten_bt_countries,palette="coolwarm")
plt.title("Top Ten Bottom countries Of Total Population (1960)")
plt.xlabel("Total population")
plt.ylabel("country")
add_value_labels(plot)

plt.subplot(2,2,2)
plot=sns.barplot(x='2022',y="Country Name",data=top_ten_bt_countries,palette="coolwarm")
plt.title("Top Ten Bottom countries Of Total Population in 2022")
plt.xlabel("Total population")
plt.ylabel("country")
add_value_labels(plot)

plt.tight_layout()
# Out:
# C:\Users\saniy\AppData\Local\Temp\ipykernel_27680\2902038964.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   plot=sns.barplot(x='1960',y="Country Name",data=top_ten_bt_countries,palette="coolwarm")
# C:\Users\saniy\AppData\Local\Temp\ipykernel_27680\2902038964.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   plot=sns.barplot(x='2022',y="Country Name",data=top_ten_bt_countries,palette="coolwarm")

# %% [markdown]
# extracted top ten countries with highest male population

# %%
df.sample(10)
# Out:
#                     Country Name Indicator Code          1960          1961  \
# 245                       Tuvalu    SP.POP.TOTL  5.598000e+03  5.648000e+03
# 50                          Cuba    SP.POP.TOTL  7.238081e+06  7.387117e+06
# 86                   Gambia, The    SP.POP.TOTL  3.980600e+05  4.089300e+05
# 165                   Mozambique    SP.POP.TOTL  6.713695e+06  6.834936e+06
# 1    Africa Eastern and Southern    SP.POP.TOTL  1.300757e+08  1.335349e+08
# 63           East Asia & Pacific    SP.POP.TOTL  1.042819e+09  1.044750e+09
# 84                     Gibraltar    SP.POP.TOTL  2.183900e+04  2.187200e+04
# 232                         Togo    SP.POP.TOTL  1.673110e+06  1.702717e+06
# 145                       Latvia    SP.POP.TOTL  2.120979e+06  2.152681e+06
# 38               Channel Islands    SP.POP.TOTL  1.108080e+05  1.117820e+05
#
#              1962          1963          1964          1965          1966  \
# 245  5.699000e+03  5.751000e+03  5.752000e+03  5.715000e+03  5.686000e+03
# 50   7.541098e+06  7.701660e+06  7.866020e+06  8.030797e+06  8.193450e+06
# 86   4.201630e+05  4.317570e+05  4.436870e+05  4.559520e+05  4.685160e+05
# 165  6.969364e+06  7.109828e+06  7.255061e+06  7.406421e+06  7.562990e+06
# 1    1.371717e+08  1.409455e+08  1.449041e+08  1.490335e+08  1.532812e+08
# 63   1.059217e+09  1.085095e+09  1.110651e+09  1.136869e+09  1.166223e+09
# 84   2.219700e+04  2.275300e+04  2.331500e+04  2.387800e+04  2.444400e+04
# 232  1.732959e+06  1.765072e+06  1.803440e+06  1.853771e+06  1.918513e+06
# 145  2.181586e+06  2.210919e+06  2.240623e+06  2.265919e+06  2.283217e+06
# 38   1.129530e+05  1.142340e+05  1.155610e+05  1.168790e+05  1.181860e+05
#
#              1967  ...          2016          2017          2018  \
# 245  5.652000e+03  ...  1.093000e+04  1.086900e+04  1.075100e+04
# 50   8.352625e+06  ...  1.126561e+07  1.124783e+07  1.122712e+07
# 86   4.815880e+05  ...  2.283769e+06  2.342189e+06  2.399632e+06
# 165  7.724550e+06  ...  2.733710e+07  2.816639e+07  2.901864e+07
# 1    1.577044e+08  ...  6.233694e+08  6.400587e+08  6.578011e+08
# 63   1.194633e+09  ...  2.317076e+09  2.333476e+09  2.347576e+09
# 84   2.501500e+04  ...  3.365800e+04  3.424500e+04  3.485400e+04
# 232  1.995890e+06  ...  7.858289e+06  8.057140e+06  8.258778e+06
# 145  2.301220e+06  ...  1.959537e+06  1.942248e+06  1.927174e+06
# 38   1.195050e+05  ...  1.638830e+05  1.643190e+05  1.649490e+05
#
#              2019          2020          2021          2022          2023  \
# 245  1.058100e+04  1.039900e+04  1.019400e+04  9.992000e+03  9.816000e+03
# 50   1.120285e+07  1.117635e+07  1.112217e+07  1.105982e+07  1.101993e+07
# 86   2.456844e+06  2.515733e+06  2.576010e+06  2.636470e+06  2.697845e+06
# 165  2.988438e+07  3.078369e+07  3.170780e+07  3.265625e+07  3.363516e+07
# 1    6.759502e+08  6.944461e+08  7.130909e+08  7.318214e+08  7.505038e+08
# 63   2.359771e+09  2.369439e+09  2.375144e+09  2.379648e+09  2.384479e+09
# 84   3.549400e+04  3.617300e+04  3.685800e+04  3.760900e+04  3.847100e+04
# 232  8.463068e+06  8.669720e+06  8.878379e+06  9.089738e+06  9.304337e+06
# 145  1.913822e+06  1.900449e+06  1.884490e+06  1.879383e+06  1.877445e+06
# 38   1.656390e+05  1.662350e+05  1.667410e+05  1.672150e+05  1.676910e+05
#
#              2024  Unnamed: 69
# 245  9.646000e+03          NaN
# 50   1.097978e+07          NaN
# 86   2.759988e+06          NaN
# 165  3.463177e+07          NaN
# 1    7.692946e+08          NaN
# 63   2.388378e+09          NaN
# 84   3.932900e+04          NaN
# 232  9.515236e+06          NaN
# 145  1.862441e+06          NaN
# 38   1.681260e+05          NaN
#
# [10 rows x 68 columns]

# %%
# filter data for total male population
total_population_male=df[df['Indicator Code']=='SP.POP.TOTL.MA.IN']
total_population_male
# Out:
# Empty DataFrame
# Columns: [Country Name, Indicator Code, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, Unnamed: 69]
# Index: []
#
# [0 rows x 68 columns]

# %%
# sort data based on total population for 2022
total_population_sort_ma = total_population_male.sort_values(by='2022',ascending=False)
total_population_sort_ma
# Out:
# Empty DataFrame
# Columns: [Country Name, Indicator Code, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, Unnamed: 69]
# Index: []
#
# [0 rows x 68 columns]

# %%
# get top 10 countries with the highest population for 2022
top_ten_male_countries = total_population_sort_ma.head(10)
print("Top Ten male Counteies Of Total Population:-")
print(top_ten_male_countries)
# Out:
# Top Ten male Counteies Of Total Population:-
# Empty DataFrame
# Columns: [Country Name, Indicator Code, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, Unnamed: 69]
# Index: []
#
# [0 rows x 68 columns]

# %% [markdown]
# THANKYOU
